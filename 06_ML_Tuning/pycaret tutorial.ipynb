# %% [markdown]
# 가상환경 생성 및 pycaret 설치 - [[Python] PyCaret Windows 10 아나콘다 설치 방법](https://dschloe.github.io/python/newpkgs/pycaret_install/)
#
# pycaret 튜토리얼 - [[ML] Pycaret으로 ML모델 쉽게 만들기](https://minimin2.tistory.com/137)

# %%
from pycaret.datasets import get_data
dataset = get_data('credit')
dataset.shape
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1      90000    2          2         2   34      0      0      0      0
# 2      50000    2          2         1   37      0      0      0      0
# 3      50000    1          2         1   57     -1      0     -1      0
# 4      50000    1          1         2   37      0      0      0      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1      0  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 2      0  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 3      0  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
# 4      0  ...    19394.0    19619.0    20024.0    2500.0    1815.0     657.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# ...

# %%
data = dataset.sample(frac=0.95, random_state=786)
data_unseen = dataset.drop(data.index)
data.reset_index(inplace=True, drop=True)
data_unseen.reset_index(inplace=True, drop=True)
print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (22800, 24)
# Unseen Data For Predictions: (1200, 24)

# %%
from pycaret.classification import *
exp_clf101 = setup(data = data, target = 'default', session_id=123)
# Out:
# <style type="text/css">
# #T_33d88_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_33d88">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33d88_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_33d88_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33d88_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_33d88_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_33d88_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_33d88_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_33d88_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_33d88_row1_col1" class="data row1 col1" >default</td>
#     </tr>
#     <tr>
#       <th id="T_33d88_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_452cc th {
#   text-align: left;
# }
# ...

# %%
rf = create_model('rf')
plot_model(rf, plot = 'auc')

# %%
plot_model(rf, plot = 'confusion_matrix')

# %%
unseen_predictions = predict_model(rf, data=data_unseen)
unseen_predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_eadf9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eadf9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_eadf9_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_eadf9_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_eadf9_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_eadf9_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_eadf9_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_eadf9_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_eadf9_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eadf9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eadf9_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
# ...

# %%
from pycaret.utils import check_metric
check_metric(unseen_predictions['default'], unseen_predictions['Label'], metric = 'Accuracy')
# Out:
# 0.8142
